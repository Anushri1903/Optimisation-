# %% [markdown]
# ## Single Vending Machine Optimization Problem

# %% [markdown]
# ## Problem Description
#
# There are a few(12) vending machines at different locations. Each machine can  occupies 5 differnt kinds of drinks soda,cola,tropics, cherry, cola can etc. The goal here to maximize the minimum days of supply (dos) for each machine.
#
# #### About Vending machine
# Input file - machines.csv
#
# Each machine has unique machine id, machine_type, list of the product types that the machine can occupy, and supply per day(spd) of each product associated to the machine id.
#
# #### About products
# There are total 5 dictict types of product ids eg. [1:soda,2:cola,3:tropics,4:cherry,5:cola can]
# each drinks has it's volumne.
#
# #### Product machine
# The volumn of the product decides how much aspece that product has in the vending machine.If vi
#
#
# machine,product,spd

# %% [markdown]
# ### Solution Approach
# A mathematical optimization model has five components, namely:
#
# * Sets and indices.
# * Parameters.
# * Decision variables.
# * Objective function(s).
# * Constraints.
# We now present a MIP formulation for the Vending Mcachine optimisation problem.

# %% [markdown]
# Decisions:
#
# (1) Which products should go in wchine vending machine
#
# (2) The ways columsn of machine has to fill
#
# (3) Max(min(sum()))

# %% [markdown]
# ## Model Formulation
#
# ### Sets
#
# $m \in M$: Set of Machines.{1,2,3,.....12}
#
# $i \in I$: Set Machine Types, {1:closed_front_1, 2:closed_front_2, 3:closed_front_3, 4:closed_front_4, 5:closed_front_5, 6:closed_front_6}.
#
# $c \in C$: Set of Columnsin a machine.{1:col1,2:col2,3:col3,4:col4,5:col5,6:col6,7:col7,8:col8,9:col9,10:col10,11:col11,12:col12}
#
# $p \in P$: product {111,222,333,444,555}
#
# $v \in V$: volume {12,16.9}
#
#
#
#
# ### Parameters
#
# $cap_{m,i,c} \in \mathbb{R}^+$: Fixed caapcity associated with machine id,machine type,machine column for $m \in M$ of type $i \in I$ of column .
#
# $spd_{m,i,p} \in \mathbb{R}^+$: Supply per day for a machine $m \in M$ and type $i \in I$ of product $p \in P$.
#
# $vol_{p,v} \in \mathbb{R}^+$: Volume of product  $p \in P$ is $v \in V$.
#
#
#
# ### Decision Variables
#
# $select_{m,i,c,p}\in \mathbb{N}^+$: Quantity of product p (in units) that can be place in machine $m of type $i in column $c.
#
#
#
# ### Objective Function
#
# - **Total costs**. We want to  Maximize the minimum days of supply (dos) for each machine.
# maximise( min(capacity_product1=sum(product1)/spd_product1,...sum(product1) ))
#
# \begin{equation}
# \text{Max} \quad Z = \sum_{p \in P}_\cdot select_{d,t_initial,t_future}+\sum_{d \in D}  h_{d,t_initial,t_future}  \cdot select_{d,t_initial,t_future} + \sum_{d \in D} \sum_{i \in I} c_{d,i} \cdot x_{d,tstore,i}  \sum_{d \in D} \sum_{j \in J} d_{d,j} \cdot y_{d,tonline,j}
# \tag{0}
# \end{equation}
#
# ### Constraints
#
# - **Column capacity constraint**. For each column  $c \in C$ ensure the products in each column is less then capacity .
# \begin{equation}
# \sum_{p \in P} select_{m,i,c,p} <= cap_{m,i,c}  \quad \forall i \in I \quad \forall tstore = {1: RDC, 3: HDC}
# \tag{1}
# \end{equation}
#
# - **One column one product constraint**. For each online  $j \in J$ ensure that its demand is fulfilled.
# \begin{equation}
# \sum_{d \in D} y_{d,tonline,j} = dj \quad \forall j \in J \quad \forall tonline = {1: EDC, 3: HDC}
# \tag{1}
# \end{equation}
#
# - **Ensure if distribution center is open before providing service to stores**. We need to ensure that we  only ship from DC $d \in D$,  if that dc has actually been built/open/ tranfer to type of DC that fulfills store's demand.
#
# for B&M Stores
# \begin{equation}
# \sum_{i \in I} x_{d,tstore,i} \leq M \cdot select_{d,t_initial,t_future} \quad \forall d \in D
# \tag{2}
# \end{equation}
#
# for online Stores
# \begin{equation}
# \sum_{j \in J} y_{d,tonline,j} \leq M \cdot select_{d,t_initial,t_future}  \quad \forall d \in D
# \tag{2}
# \end{equation}

# %%
import gurobipy as gp
import pandas as pd
import numpy as np
from gurobipy import multidict
from gurobipy import GRB
from gurobipy import min_

# %%
### Reading required files
capacity = pd.read_csv('capacity_matrix.csv')
items = pd.read_csv('items.csv')
machines = pd.read_csv('machines.csv')
columns_shelf=capacity.columns
columns_shelf[2:14]

## Handling Single Machine 
machines_single = machines[machines['machine_id']==1]

## Adding column_name optimions column to the machines 
machines_single=machines_single.merge(pd.DataFrame(columns_shelf[2:14].values), how='cross')
machines_single.rename(columns = {0:'Column'}, inplace = True)

# %%
items
# Out:
#    item_id      name           pack
# 0      111      soda  16.9oz bottle
# 1      222      cola  16.9oz bottle
# 2      333   tropics  16.9oz bottle
# 3      444    cherry       12oz can
# 4      555  cola can       12oz can

# %%
machines
# Out:
#     machine_id    machine_type   item_id   spd
# 0            1  closed_front_1       111   5.6
# 1            1  closed_front_1       222   5.4
# 2            1  closed_front_1       333   3.6
# 3            1  closed_front_1       444   1.5
# 4            1  closed_front_1       555   1.6
# 5            2  closed_front_2       111   5.6
# 6            2  closed_front_2       222   5.4
# 7            2  closed_front_2       333   3.6
# 8            2  closed_front_2       444   1.5
# 9            2  closed_front_2       555   1.6
# 10           3  closed_front_3       111   5.6
# 11           3  closed_front_3       222   5.4
# 12           3  closed_front_3       333   3.6
# 13           3  closed_front_3       444   1.5
# 14           3  closed_front_3       555   1.6
# 15           4  closed_front_4       111   5.6
# 16           4  closed_front_4       222   5.4
# 17           4  closed_front_4       333   3.6
# 18           4  closed_front_4       444   1.5
# 19           4  closed_front_4       555   1.6
# 20           5  closed_front_5       111   5.6
# 21           5  closed_front_5       222   5.4
# 22           5  closed_front_5       333   3.6
# 23           5  closed_front_5       444   1.5
# 24           5  closed_front_5       555   1.6
# 25           6  closed_front_6       111   5.6
# 26           6  closed_front_6       222   5.4
# 27           6  closed_front_6       333   3.6
# 28           6  closed_front_6       444   1.5
# 29           6  closed_front_6       555   1.6
# 30           7  closed_front_1       111  12.1
# 31           7  closed_front_1       222   9.8
# 32           7  closed_front_1       333   8.6
# 33           7  closed_front_1       444   4.7
# 34           7  closed_front_1       555  12.1
# 35           8  closed_front_2       111  12.1
# 36           8  closed_front_2       222   9.8
# 37           8  closed_front_2       333   8.6
# 38           8  closed_front_2       444   4.7
# 39           8  closed_front_2       555  12.1
# 40           9  closed_front_3      soda  12.1
# 41           9  closed_front_3      cola   9.8
# 42           9  closed_front_3   tropics   8.6
# 43           9  closed_front_3    cherry   4.7
# 44           9  closed_front_3  cola can  12.1
# 45          10  closed_front_4      soda  12.1
# 46          10  closed_front_4      cola   9.8
# 47          10  closed_front_4   tropics   8.6
# 48          10  closed_front_4    cherry   4.7
# 49          10  closed_front_4  cola can  12.1
# 50          11  closed_front_5      soda  12.1
# 51          11  closed_front_5      cola   9.8
# 52          11  closed_front_5   tropics   8.6
# 53          11  closed_front_5    cherry   4.7
# 54          11  closed_front_5  cola can  12.1
# 55          12  closed_front_6      soda  12.1
# 56          12  closed_front_6      cola   9.8
# 57          12  closed_front_6   tropics   8.6
# 58          12  closed_front_6    cherry   4.7
# 59          12  closed_front_6  cola can  12.1

# %%
## Data Correction- Not needed for single machine 
"""
machines2 = machines
correction = {'soda':111 , 'cola':222, 'tropics':333, 'cherry':444,'cola can':555}
machines=machines2.replace({"item_id": correction})
"""
# Out:
# '\nmachines2 = machines\ncorrection = {\'soda\':111 , \'cola\':222, \'tropics\':333, \'cherry\':444,\'cola can\':555}\nmachines=machines2.replace({"item_id": correction})\n'

# %%
#Sets-Single machine 
products = list(items['item_id'].unique())
machine = list(machines_single['machine_id'].unique())
machines_types = list(machines_single['machine_type'].unique())
columns = list(columns_shelf[2:14])#list(range(1,13)) ## conver to auto
volumns = list(capacity['pack'].unique())

# %%
#Single machine -Parameters -1
cap={}
for j in machines_types: 
    for k in volumns:
        for col in columns:
          column_name = col #'col'+str(col)
          cap[j,k,column_name]=capacity.loc[(capacity['machine_type']==j) & (capacity['pack']==k),column_name].values[0]
            

## Single Parameters -2
#𝑠𝑝𝑑𝑚,𝑖,𝑝∈ℝ+ : Supply per day for a machine 𝑚∈𝑀 and type 𝑖∈𝐼 of product 𝑝∈𝑃.
    
spdm = {}
spdm={j:k for j in zip(machines_single['machine_id'],machines_single['machine_type'],machines_single['item_id']) for k in machines.loc[(machines_single['machine_id']==j[0]) & (machines_single['machine_type']==j[1]) & (machines_single['item_id']==j[2]),'spd']}


## Parameters -3
#𝑣𝑜𝑙𝑝,𝑣∈ℝ+ : Volume of product  𝑝∈𝑃  is  𝑣∈𝑉 .
volp ={p:v for p in items['item_id'] for v in items.loc[items['item_id']==p,'pack'] }

# %%
## Decision Variable -single machine 
select1 ={j:0 for j in zip(machines_single['machine_id'],machines_single['machine_type'],machines_single['item_id'],machines_single['Column'])}

# %%
combinations, scores = gp.multidict(select1)

# %%
#combinations

# %%
##Single mahine - Start model  create decision variable -

model = gp.Model('VendingMachineOptimization_singlemachine')
select_single = model.addVars(combinations, vtype=GRB.BINARY, name='select2')  #(1,'closed_front_2', '555', 1):12(number of products)
#select = model.addVars(combinations, obj=scores, name="prod_col")

# %%
## Single machine -objective value 
#obj = gp.quicksum(((select_single[m,i,p,c]*cap[i,volp[int(p)],c])/spdm[m,i,p]) for m,i,p,c in select1.keys())
#model.setObjective(obj, GRB.MAXIMIZE)


# Production capacity limits

# %%
## Building objective finction for descrete values 
M=len(products)
y = model.addVars(products, lb=-GRB.INFINITY, name="y")
#z = model.addVars(1, lb=-GRB.INFINITY, name="z")
z = model.addVar(vtype=GRB.CONTINUOUS, name="Z")
#u = model.addVars(M, name="u")

#model.addConstrs((y[p] == gp.quicksum(select_single[m,i,str(p),c]*cap[i,volp[int(p)],c] for m,i,g,c in select1.keys()) for p in products),name="set_y")
model.addConstrs((y[p] == gp.quicksum(select_single[m,i,str(p),c]*cap[i,volp[int(p)],c] for m,i,g,c in select1.keys()) 
                  for p in products),name="set_y")

#model.addConstr(min_(y,0),name="maxconstr")
#model.addConstrs((z[i] == min_(y[i]) for i in products), name="set_minobj")
model.addConstr(z == min_(y), name="min constraint")

model.setObjective(z, sense=GRB.MAXIMIZE)

#model.setObjective(min_(y,0), GRB.MAXIMIZE)
#m.addConstr(z == min_(x, y, constant=3))
#model.addConstrs((u[i] == abs_(z[i]) for i products)), name="set_u")
#model.addConstr(minobj == u.sum(), name="set_minobj")

# %%
## Modification in above 
y = model.addVars(products, lb=-GRB.INFINITY, name="y")
z = model.addVar(vtype=GRB.CONTINUOUS, name="Z")
model.addConstrs((y[p] == gp.quicksum(select_single[m,i,str(p),c]*cap[i,volp[int(p)],c] for m,i,g,c in select1.keys())/spdm[1,'closed_front_1',str(p)] 
                  for p in products),name="set_y")
model.addConstr(z == min_(y), name="min constraint")
model.setObjective(z, sense=GRB.MAXIMIZE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-92120e2ac7d8> in <module>
#       1 ## Modification in above
# ----> 2 y = model.addVars(products, lb=-GRB.INFINITY, name="y")
#       3 z = model.addVar(vtype=GRB.CONTINUOUS, name="Z")
#       4 model.addConstrs((y[p] == gp.quicksum(select_single[m,i,str(p),c]*cap[i,volp[int(p)],c] for m,i,g,c in select1.keys())/spdm[1,'closed_front_1',str(p)]
#       5                   for p in products),name="set_y")
#
# NameError: name 'model' is not defined

# %%
y
# Out:
# {111: <gurobi.Var *Awaiting Model Update*>,
#  222: <gurobi.Var *Awaiting Model Update*>,
#  333: <gurobi.Var *Awaiting Model Update*>,
#  444: <gurobi.Var *Awaiting Model Update*>,
#  555: <gurobi.Var *Awaiting Model Update*>}

# %%
select_single
# Out:
# {(1,
#   'closed_front_1',
#   '111',
#   'col1'): <gurobi.Var select2[1,closed_front_1,111,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col2'): <gurobi.Var select2[1,closed_front_1,111,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col3'): <gurobi.Var select2[1,closed_front_1,111,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col4'): <gurobi.Var select2[1,closed_front_1,111,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col5'): <gurobi.Var select2[1,closed_front_1,111,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col6'): <gurobi.Var select2[1,closed_front_1,111,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col7'): <gurobi.Var select2[1,closed_front_1,111,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col8'): <gurobi.Var select2[1,closed_front_1,111,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col9'): <gurobi.Var select2[1,closed_front_1,111,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Var select2[1,closed_front_1,111,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Var select2[1,closed_front_1,111,col11] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Var select2[1,closed_front_1,111,col12] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col1'): <gurobi.Var select2[1,closed_front_1,222,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col2'): <gurobi.Var select2[1,closed_front_1,222,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col3'): <gurobi.Var select2[1,closed_front_1,222,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col4'): <gurobi.Var select2[1,closed_front_1,222,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col5'): <gurobi.Var select2[1,closed_front_1,222,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col6'): <gurobi.Var select2[1,closed_front_1,222,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col7'): <gurobi.Var select2[1,closed_front_1,222,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col8'): <gurobi.Var select2[1,closed_front_1,222,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col9'): <gurobi.Var select2[1,closed_front_1,222,col9] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Var select2[1,closed_front_1,222,col10] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Var select2[1,closed_front_1,222,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Var select2[1,closed_front_1,222,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col1'): <gurobi.Var select2[1,closed_front_1,333,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col2'): <gurobi.Var select2[1,closed_front_1,333,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col3'): <gurobi.Var select2[1,closed_front_1,333,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col4'): <gurobi.Var select2[1,closed_front_1,333,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col5'): <gurobi.Var select2[1,closed_front_1,333,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col6'): <gurobi.Var select2[1,closed_front_1,333,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col7'): <gurobi.Var select2[1,closed_front_1,333,col7] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col8'): <gurobi.Var select2[1,closed_front_1,333,col8] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col9'): <gurobi.Var select2[1,closed_front_1,333,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Var select2[1,closed_front_1,333,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Var select2[1,closed_front_1,333,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Var select2[1,closed_front_1,333,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col1'): <gurobi.Var select2[1,closed_front_1,444,col1] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col2'): <gurobi.Var select2[1,closed_front_1,444,col2] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col3'): <gurobi.Var select2[1,closed_front_1,444,col3] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col4'): <gurobi.Var select2[1,closed_front_1,444,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col5'): <gurobi.Var select2[1,closed_front_1,444,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col6'): <gurobi.Var select2[1,closed_front_1,444,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col7'): <gurobi.Var select2[1,closed_front_1,444,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col8'): <gurobi.Var select2[1,closed_front_1,444,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col9'): <gurobi.Var select2[1,closed_front_1,444,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Var select2[1,closed_front_1,444,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Var select2[1,closed_front_1,444,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Var select2[1,closed_front_1,444,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col1'): <gurobi.Var select2[1,closed_front_1,555,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col2'): <gurobi.Var select2[1,closed_front_1,555,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col3'): <gurobi.Var select2[1,closed_front_1,555,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col4'): <gurobi.Var select2[1,closed_front_1,555,col4] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col5'): <gurobi.Var select2[1,closed_front_1,555,col5] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col6'): <gurobi.Var select2[1,closed_front_1,555,col6] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col7'): <gurobi.Var select2[1,closed_front_1,555,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col8'): <gurobi.Var select2[1,closed_front_1,555,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col9'): <gurobi.Var select2[1,closed_front_1,555,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Var select2[1,closed_front_1,555,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Var select2[1,closed_front_1,555,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Var select2[1,closed_front_1,555,col12] (value -0.0)>}

# %%
""" # Reference
import gurobipy as gp
from gurobipy import GRB

m = gp.Model("test")
x = m.addVars(5, vtype=GRB.CONTINUOUS, lb=0, ub=100, name="X")
z = m.addVar(vtype=GRB.CONTINUOUS, name="Z")
# Add constraint z = max(x1,x2,x3,x4,x5)
m.addConstr(z == gp.max_(x), name="max_contraint")
m.setObjective(z, sense=GRB.MINIMIZE)
"""
# Out:
#   File "<ipython-input-227-bcf227de1bbc>", line 10
#     """
#        ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
## Single machine - Constraint1 
"""
model.addConstrs((select_single[m,i,p,c]*cap[i,volp[int(p)],c] <= cap[i,volp[int(p)],c] for m,i,p,c in select_single.keys()),
                 name="Single_column_capacity")"""
# Out:
# '\nmodel.addConstrs((select_single[m,i,p,c]*cap[i,volp[int(p)],c] <= cap[i,volp[int(p)],c] for m,i,p,c in select_single.keys()),\n                 name="Single_column_capacity")'

# %%
## Single machine - Constraint2
model.addConstrs((select_single.sum(m,i,'*',c) <= 1
             for m,i,p,c in select_single.keys()),
            name="single_1_col_1prod")
# Out:
# {(1, 'closed_front_1', '111', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>}

# %%
## Single machine Minimum demand has to be satisfied - Constraint2
model.addConstrs((select_single.sum(m,i,p,'*')*cap[i,volp[int(p)],c] >= spdm[m,i,p]
             for m,i,p,c in select_single.keys()),
            name="single_min_demand")
# Out:
# {(1, 'closed_front_1', '111', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>}

# %%
# Find the optimal solution
model.optimize()
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 125 rows, 66 columns and 665 nonzeros
# Model fingerprint: 0xda6acfa1
# Model has 1 general constraint
# Variable types: 6 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 108 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 61 columns, 125 nonzeros
# Variable types: 1 continuous, 60 integer (60 binary)
#
# Root relaxation: objective 1.489842e+01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   14.89842    0    8   -0.00000   14.89842      -     -    0s
# H    0     0                      10.1851852   14.89842  46.3%     -    0s
# H    0     0                      11.1570248   14.89842  33.5%     -    0s
#      0     0   13.52644    0    8   11.15702   13.52644  21.2%     -    0s
#      0     0 infeasible    0        11.15702   11.15702  0.00%     -    0s
#      0     0 infeasible    0        11.15702   11.15702  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#
# Explored 1 nodes (51 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 11.157 10.1852 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.115702479339e+01, best bound 1.115702479339e+01, gap 0.0000%

# %%
### Post processing output values 
product_flow = pd.DataFrame(columns=["Machine_id", "Machine_type", "Product","Column","Values","Capacity"])
for arc in combinations:
    #if select_single[arc].x > 1e-6:
    product_flow = product_flow.append({"Machine_id": arc[0], "Machine_type": arc[1],"Product": arc[2], "Column": arc[3],"Values": select_single[arc].x,"Capacity": select_single[arc].x*cap[arc[1],volp[int(arc[2])],arc[3]],"dos":select_single[arc].x*cap[arc[1],volp[int(arc[2])],arc[3]]/spdm[arc[0],arc[1],str(arc[2])],"spd":spdm[arc[0],arc[1],str(arc[2])]}, ignore_index=True)  
#product_flow.index=[''] * len(product_flow)
product_flow
# Out:
#    Machine_id    Machine_type Product Column  Values  Capacity       dos   spd
# 0           1  closed_front_1     111   col1    -0.0      -0.0 -0.000000   5.4
# 1           1  closed_front_1     111   col2    -0.0      -0.0 -0.000000   5.4
# 2           1  closed_front_1     111   col3    -0.0      -0.0 -0.000000   5.4
# 3           1  closed_front_1     111   col4     1.0      11.0  2.037037   5.4
# 4           1  closed_front_1     111   col5    -0.0      -0.0 -0.000000   5.4
# 5           1  closed_front_1     111   col6    -0.0      -0.0 -0.000000   5.4
# 6           1  closed_front_1     111   col7     1.0      11.0  2.037037   5.4
# 7           1  closed_front_1     111   col8    -0.0      -0.0 -0.000000   5.4
# 8           1  closed_front_1     111   col9    -0.0      -0.0 -0.000000   5.4
# 9           1  closed_front_1     111  col10    -0.0      -0.0 -0.000000   5.4
# 10          1  closed_front_1     111  col11    -0.0      -0.0 -0.000000   5.4
# 11          1  closed_front_1     111  col12    -0.0      -0.0 -0.000000   5.4
# 12          1  closed_front_1     222   col1    -0.0      -0.0 -0.000000   1.5
# 13          1  closed_front_1     222   col2    -0.0      -0.0 -0.000000   1.5
# 14          1  closed_front_1     222   col3    -0.0      -0.0 -0.000000   1.5
# 15          1  closed_front_1     222   col4    -0.0      -0.0 -0.000000   1.5
# 16          1  closed_front_1     222   col5    -0.0      -0.0 -0.000000   1.5
# 17          1  closed_front_1     222   col6    -0.0      -0.0 -0.000000   1.5
# 18          1  closed_front_1     222   col7    -0.0      -0.0 -0.000000   1.5
# 19          1  closed_front_1     222   col8    -0.0      -0.0 -0.000000   1.5
# 20          1  closed_front_1     222   col9    -0.0      -0.0 -0.000000   1.5
# 21          1  closed_front_1     222  col10    -0.0      -0.0 -0.000000   1.5
# 22          1  closed_front_1     222  col11     1.0      11.0  7.333333   1.5
# 23          1  closed_front_1     222  col12    -0.0      -0.0 -0.000000   1.5
# 24          1  closed_front_1     333   col1    -0.0      -0.0 -0.000000  12.1
# 25          1  closed_front_1     333   col2     1.0      11.0  0.909091  12.1
# 26          1  closed_front_1     333   col3     1.0      11.0  0.909091  12.1
# 27          1  closed_front_1     333   col4    -0.0      -0.0 -0.000000  12.1
# 28          1  closed_front_1     333   col5    -0.0      -0.0 -0.000000  12.1
# 29          1  closed_front_1     333   col6    -0.0      -0.0 -0.000000  12.1
# 30          1  closed_front_1     333   col7    -0.0      -0.0 -0.000000  12.1
# 31          1  closed_front_1     333   col8    -0.0      -0.0 -0.000000  12.1
# 32          1  closed_front_1     333   col9    -0.0      -0.0 -0.000000  12.1
# 33          1  closed_front_1     333  col10     1.0      11.0  0.909091  12.1
# 34          1  closed_front_1     333  col11     0.0       0.0  0.000000  12.1
# 35          1  closed_front_1     333  col12    -0.0      -0.0 -0.000000  12.1
# 36          1  closed_front_1     444   col1     1.0       9.0  1.046512   8.6
# 37          1  closed_front_1     444   col2    -0.0      -0.0 -0.000000   8.6
# 38          1  closed_front_1     444   col3    -0.0      -0.0 -0.000000   8.6
# 39          1  closed_front_1     444   col4    -0.0      -0.0 -0.000000   8.6
# 40          1  closed_front_1     444   col5    -0.0      -0.0 -0.000000   8.6
# 41          1  closed_front_1     444   col6     1.0       9.0  1.046512   8.6
# 42          1  closed_front_1     444   col7     0.0       0.0  0.000000   8.6
# 43          1  closed_front_1     444   col8    -0.0      -0.0 -0.000000   8.6
# 44          1  closed_front_1     444   col9    -0.0      -0.0 -0.000000   8.6
# 45          1  closed_front_1     444  col10    -0.0      -0.0 -0.000000   8.6
# 46          1  closed_front_1     444  col11    -0.0      -0.0 -0.000000   8.6
# 47          1  closed_front_1     444  col12     1.0       9.0  1.046512   8.6
# 48          1  closed_front_1     555   col1    -0.0      -0.0 -0.000000  12.1
# 49          1  closed_front_1     555   col2    -0.0      -0.0 -0.000000  12.1
# 50          1  closed_front_1     555   col3    -0.0      -0.0 -0.000000  12.1
# 51          1  closed_front_1     555   col4     0.0       0.0  0.000000  12.1
# 52          1  closed_front_1     555   col5     1.0       9.0  0.743802  12.1
# 53          1  closed_front_1     555   col6    -0.0      -0.0 -0.000000  12.1
# 54          1  closed_front_1     555   col7    -0.0      -0.0 -0.000000  12.1
# 55          1  closed_front_1     555   col8     1.0       9.0  0.743802  12.1
# 56          1  closed_front_1     555   col9     1.0       9.0  0.743802  12.1
# 57          1  closed_front_1     555  col10    -0.0      -0.0 -0.000000  12.1
# 58          1  closed_front_1     555  col11    -0.0      -0.0 -0.000000  12.1
# 59          1  closed_front_1     555  col12     0.0       0.0  0.000000  12.1

# %%
spdm
# Out:
# {(1, 'closed_front_1', '111'): 5.4,
#  (1, 'closed_front_1', '222'): 1.5,
#  (1, 'closed_front_1', '333'): 12.1,
#  (1, 'closed_front_1', '444'): 8.6,
#  (1, 'closed_front_1', '555'): 12.1}

# %%
h=product_flow[['Machine_id','Machine_type','Product'
                ,'Values','Capacity','dos','spd']]
k=h.groupby(['Machine_id','Machine_type','Product','spd','Values'])

# %%
k.first()
# Out:
#                                                Capacity       dos
# Machine_id Machine_type   Product spd  Values
# 1          closed_front_1 111     5.4  -0.0        -0.0 -0.000000
#                                         1.0        11.0  2.037037
#                           222     1.5  -0.0        -0.0 -0.000000
#                                         1.0        11.0  7.333333
#                           333     12.1 -0.0        -0.0 -0.000000
#                                         1.0        11.0  0.909091
#                           444     8.6  -0.0        -0.0 -0.000000
#                                         1.0         9.0  1.046512
#                           555     12.1 -0.0        -0.0 -0.000000
#                                         1.0         9.0  0.743802

# %%
z
# Out:
# <gurobi.Var Z (value 11.157024793388429)>

# %%
y
# Out:
# {111: <gurobi.Var y[111] (value 20.370370370370367)>,
#  222: <gurobi.Var y[222] (value 36.666666666666664)>,
#  333: <gurobi.Var y[333] (value 13.636363636363637)>,
#  444: <gurobi.Var y[444] (value 15.697674418604652)>,
#  555: <gurobi.Var y[555] (value 11.157024793388429)>}

# %%
tmp ={j:3 for j in zip(machines_single['machine_id'],machines_single['machine_type'],machines_single['item_id'],machines_single['Column'])}

# %%
tmp()
# Out:
# {(1, 'closed_front_1', '111', 'col1'): 3,
#  (1, 'closed_front_1', '111', 'col2'): 3,
#  (1, 'closed_front_1', '111', 'col3'): 3,
#  (1, 'closed_front_1', '111', 'col4'): 3,
#  (1, 'closed_front_1', '111', 'col5'): 3,
#  (1, 'closed_front_1', '111', 'col6'): 3,
#  (1, 'closed_front_1', '111', 'col7'): 3,
#  (1, 'closed_front_1', '111', 'col8'): 3,
#  (1, 'closed_front_1', '111', 'col9'): 3,
#  (1, 'closed_front_1', '111', 'col10'): 3,
#  (1, 'closed_front_1', '111', 'col11'): 3,
#  (1, 'closed_front_1', '111', 'col12'): 3,
#  (1, 'closed_front_1', '222', 'col1'): 3,
#  (1, 'closed_front_1', '222', 'col2'): 3,
#  (1, 'closed_front_1', '222', 'col3'): 3,
#  (1, 'closed_front_1', '222', 'col4'): 3,
#  (1, 'closed_front_1', '222', 'col5'): 3,
#  (1, 'closed_front_1', '222', 'col6'): 3,
#  (1, 'closed_front_1', '222', 'col7'): 3,
#  (1, 'closed_front_1', '222', 'col8'): 3,
#  (1, 'closed_front_1', '222', 'col9'): 3,
#  (1, 'closed_front_1', '222', 'col10'): 3,
#  (1, 'closed_front_1', '222', 'col11'): 3,
#  (1, 'closed_front_1', '222', 'col12'): 3,
#  (1, 'closed_front_1', '333', 'col1'): 3,
#  (1, 'closed_front_1', '333', 'col2'): 3,
#  (1, 'closed_front_1', '333', 'col3'): 3,
#  (1, 'closed_front_1', '333', 'col4'): 3,
#  (1, 'closed_front_1', '333', 'col5'): 3,
#  (1, 'closed_front_1', '333', 'col6'): 3,
#  (1, 'closed_front_1', '333', 'col7'): 3,
#  (1, 'closed_front_1', '333', 'col8'): 3,
#  (1, 'closed_front_1', '333', 'col9'): 3,
#  (1, 'closed_front_1', '333', 'col10'): 3,
#  (1, 'closed_front_1', '333', 'col11'): 3,
#  (1, 'closed_front_1', '333', 'col12'): 3,
#  (1, 'closed_front_1', '444', 'col1'): 3,
#  (1, 'closed_front_1', '444', 'col2'): 3,
#  (1, 'closed_front_1', '444', 'col3'): 3,
#  (1, 'closed_front_1', '444', 'col4'): 3,
#  (1, 'closed_front_1', '444', 'col5'): 3,
#  (1, 'closed_front_1', '444', 'col6'): 3,
#  (1, 'closed_front_1', '444', 'col7'): 3,
#  (1, 'closed_front_1', '444', 'col8'): 3,
#  (1, 'closed_front_1', '444', 'col9'): 3,
#  (1, 'closed_front_1', '444', 'col10'): 3,
#  (1, 'closed_front_1', '444', 'col11'): 3,
#  (1, 'closed_front_1', '444', 'col12'): 3,
#  (1, 'closed_front_1', '555', 'col1'): 3,
#  (1, 'closed_front_1', '555', 'col2'): 3,
#  (1, 'closed_front_1', '555', 'col3'): 3,
#  (1, 'closed_front_1', '555', 'col4'): 3,
#  (1, 'closed_front_1', '555', 'col5'): 3,
#  (1, 'closed_front_1', '555', 'col6'): 3,
#  (1, 'closed_front_1', '555', 'col7'): 3,
#  (1, 'closed_front_1', '555', 'col8'): 3,
#  (1, 'closed_front_1', '555', 'col9'): 3,
#  (1, 'closed_front_1', '555', 'col10'): 3,
#  (1, 'closed_front_1', '555', 'col11'): 3,
#  (1, 'closed_front_1', '555', 'col12'): 3}

# %%
## Modification in above 
y = model.addVars(products, lb=-GRB.INFINITY, name="y")
z = model.addVar(vtype=GRB.CONTINUOUS, name="Z")
model.addConstrs((y[p] == gp.quicksum(select_single[1,'closed_front_1',str(p),c]*cap['closed_front_1',volp[int(p)],c] for c in columns)/spdm[1,'closed_front_1',str(p)] 
                  for p in products),name="set_y")
model.addConstr(z == min_(y), name="min constraint")
model.setObjective(z, sense=GRB.MAXIMIZE)

# %%
## Single machine Minimum demand has to be satisfied - Constraint2
model.addConstrs((select_single.sum(m,i,p,'*')*cap[i,volp[int(p)],c] >= spdm[m,i,p]
             for m,i,p,c in select_single.keys()),
            name="single_min_demand")
# Out:
# {(1, 'closed_front_1', '111', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>}

# %%
## Single machine - Constraint2
model.addConstrs((select_single.sum(m,i,'*',c) <= 1
             for m,i,p,c in select_single.keys()),
            name="single_1_col_1prod")
# Out:
# {(1, 'closed_front_1', '111', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '111', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '222', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '333', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '444', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col1'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col2'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col3'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col4'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col5'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col6'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col7'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col8'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'closed_front_1', '555', 'col9'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Constr *Awaiting Model Update*>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Constr *Awaiting Model Update*>}

# %%
select_single
# Out:
# {(1,
#   'closed_front_1',
#   '111',
#   'col1'): <gurobi.Var select2[1,closed_front_1,111,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col2'): <gurobi.Var select2[1,closed_front_1,111,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col3'): <gurobi.Var select2[1,closed_front_1,111,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col4'): <gurobi.Var select2[1,closed_front_1,111,col4] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col5'): <gurobi.Var select2[1,closed_front_1,111,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col6'): <gurobi.Var select2[1,closed_front_1,111,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col7'): <gurobi.Var select2[1,closed_front_1,111,col7] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col8'): <gurobi.Var select2[1,closed_front_1,111,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col9'): <gurobi.Var select2[1,closed_front_1,111,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col10'): <gurobi.Var select2[1,closed_front_1,111,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col11'): <gurobi.Var select2[1,closed_front_1,111,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '111',
#   'col12'): <gurobi.Var select2[1,closed_front_1,111,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col1'): <gurobi.Var select2[1,closed_front_1,222,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col2'): <gurobi.Var select2[1,closed_front_1,222,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col3'): <gurobi.Var select2[1,closed_front_1,222,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col4'): <gurobi.Var select2[1,closed_front_1,222,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col5'): <gurobi.Var select2[1,closed_front_1,222,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col6'): <gurobi.Var select2[1,closed_front_1,222,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col7'): <gurobi.Var select2[1,closed_front_1,222,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col8'): <gurobi.Var select2[1,closed_front_1,222,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col9'): <gurobi.Var select2[1,closed_front_1,222,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col10'): <gurobi.Var select2[1,closed_front_1,222,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col11'): <gurobi.Var select2[1,closed_front_1,222,col11] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '222',
#   'col12'): <gurobi.Var select2[1,closed_front_1,222,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col1'): <gurobi.Var select2[1,closed_front_1,333,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col2'): <gurobi.Var select2[1,closed_front_1,333,col2] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col3'): <gurobi.Var select2[1,closed_front_1,333,col3] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col4'): <gurobi.Var select2[1,closed_front_1,333,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col5'): <gurobi.Var select2[1,closed_front_1,333,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col6'): <gurobi.Var select2[1,closed_front_1,333,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col7'): <gurobi.Var select2[1,closed_front_1,333,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col8'): <gurobi.Var select2[1,closed_front_1,333,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col9'): <gurobi.Var select2[1,closed_front_1,333,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col10'): <gurobi.Var select2[1,closed_front_1,333,col10] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col11'): <gurobi.Var select2[1,closed_front_1,333,col11] (value 0.0)>,
#  (1,
#   'closed_front_1',
#   '333',
#   'col12'): <gurobi.Var select2[1,closed_front_1,333,col12] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col1'): <gurobi.Var select2[1,closed_front_1,444,col1] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col2'): <gurobi.Var select2[1,closed_front_1,444,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col3'): <gurobi.Var select2[1,closed_front_1,444,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col4'): <gurobi.Var select2[1,closed_front_1,444,col4] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col5'): <gurobi.Var select2[1,closed_front_1,444,col5] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col6'): <gurobi.Var select2[1,closed_front_1,444,col6] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col7'): <gurobi.Var select2[1,closed_front_1,444,col7] (value 0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col8'): <gurobi.Var select2[1,closed_front_1,444,col8] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col9'): <gurobi.Var select2[1,closed_front_1,444,col9] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col10'): <gurobi.Var select2[1,closed_front_1,444,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col11'): <gurobi.Var select2[1,closed_front_1,444,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '444',
#   'col12'): <gurobi.Var select2[1,closed_front_1,444,col12] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col1'): <gurobi.Var select2[1,closed_front_1,555,col1] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col2'): <gurobi.Var select2[1,closed_front_1,555,col2] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col3'): <gurobi.Var select2[1,closed_front_1,555,col3] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col4'): <gurobi.Var select2[1,closed_front_1,555,col4] (value 0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col5'): <gurobi.Var select2[1,closed_front_1,555,col5] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col6'): <gurobi.Var select2[1,closed_front_1,555,col6] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col7'): <gurobi.Var select2[1,closed_front_1,555,col7] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col8'): <gurobi.Var select2[1,closed_front_1,555,col8] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col9'): <gurobi.Var select2[1,closed_front_1,555,col9] (value 1.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col10'): <gurobi.Var select2[1,closed_front_1,555,col10] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col11'): <gurobi.Var select2[1,closed_front_1,555,col11] (value -0.0)>,
#  (1,
#   'closed_front_1',
#   '555',
#   'col12'): <gurobi.Var select2[1,closed_front_1,555,col12] (value 0.0)>}

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 250 rows, 72 columns and 1750 nonzeros
# Model fingerprint: 0xa3a702c5
# Model has 2 general constraints
# Variable types: 12 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [7e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# MIP start from previous solve produced solution with objective 2.2314 (0.01s)
# Loaded MIP start from previous solve with objective 2.2314
#
# Presolve removed 229 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 21 rows, 65 columns, 133 nonzeros
# Variable types: 1 continuous, 64 integer (60 binary)
#
# Root relaxation: objective 2.608696e+00, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.60870    0    3    2.23140    2.60870  16.9%     -    0s
#
# Cutting planes:
#   StrongCG: 2
#
# Explored 1 nodes (45 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2.2314
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.231404958678e+00, best bound 2.231404958678e+00, gap 0.0000%

# %%
y
# Out:
# {111: <gurobi.Var y[111] (value 4.0740740740740735)>,
#  222: <gurobi.Var y[222] (value 7.333333333333333)>,
#  333: <gurobi.Var y[333] (value 2.7272727272727275)>,
#  444: <gurobi.Var y[444] (value 3.1395348837209305)>,
#  555: <gurobi.Var y[555] (value 2.231404958677686)>}

# %%
z
# Out:
# <gurobi.Var Z (value 2.231404958677686)>

# %%
### Post processing output values 
product_flow = pd.DataFrame(columns=["Machine_id", "Machine_type", "Product","Column","Values","Capacity"])
for arc in combinations:
    #if select_single[arc].x > 1e-6:
    product_flow = product_flow.append({"Machine_id": arc[0], "Machine_type": arc[1],"Product": arc[2], "Column": arc[3],"Values": select_single[arc].x,"Capacity": select_single[arc].x*cap[arc[1],volp[int(arc[2])],arc[3]],"dos":select_single[arc].x*cap[arc[1],volp[int(arc[2])],arc[3]]/spdm[arc[0],arc[1],str(arc[2])],"spd":spdm[arc[0],arc[1],str(arc[2])]}, ignore_index=True)  
#product_flow.index=[''] * len(product_flow)
product_flow
# Out:
#    Machine_id    Machine_type Product Column  Values  Capacity       dos   spd
# 0           1  closed_front_1     111   col1     0.0       0.0  0.000000   5.4
# 1           1  closed_front_1     111   col2     0.0       0.0  0.000000   5.4
# 2           1  closed_front_1     111   col3     0.0       0.0  0.000000   5.4
# 3           1  closed_front_1     111   col4     1.0      11.0  2.037037   5.4
# 4           1  closed_front_1     111   col5     0.0       0.0  0.000000   5.4
# 5           1  closed_front_1     111   col6     0.0       0.0  0.000000   5.4
# 6           1  closed_front_1     111   col7     1.0      11.0  2.037037   5.4
# 7           1  closed_front_1     111   col8     0.0       0.0  0.000000   5.4
# 8           1  closed_front_1     111   col9     0.0       0.0  0.000000   5.4
# 9           1  closed_front_1     111  col10     0.0       0.0  0.000000   5.4
# 10          1  closed_front_1     111  col11     0.0       0.0  0.000000   5.4
# 11          1  closed_front_1     111  col12     0.0       0.0  0.000000   5.4
# 12          1  closed_front_1     222   col1     0.0       0.0  0.000000   1.5
# 13          1  closed_front_1     222   col2     0.0       0.0  0.000000   1.5
# 14          1  closed_front_1     222   col3     0.0       0.0  0.000000   1.5
# 15          1  closed_front_1     222   col4     0.0       0.0  0.000000   1.5
# 16          1  closed_front_1     222   col5     0.0       0.0  0.000000   1.5
# 17          1  closed_front_1     222   col6     0.0       0.0  0.000000   1.5
# 18          1  closed_front_1     222   col7     0.0       0.0  0.000000   1.5
# 19          1  closed_front_1     222   col8     0.0       0.0  0.000000   1.5
# 20          1  closed_front_1     222   col9     0.0       0.0  0.000000   1.5
# 21          1  closed_front_1     222  col10     0.0       0.0  0.000000   1.5
# 22          1  closed_front_1     222  col11     1.0      11.0  7.333333   1.5
# 23          1  closed_front_1     222  col12     0.0       0.0  0.000000   1.5
# 24          1  closed_front_1     333   col1     0.0       0.0  0.000000  12.1
# 25          1  closed_front_1     333   col2     1.0      11.0  0.909091  12.1
# 26          1  closed_front_1     333   col3     1.0      11.0  0.909091  12.1
# 27          1  closed_front_1     333   col4     0.0       0.0  0.000000  12.1
# 28          1  closed_front_1     333   col5     0.0       0.0  0.000000  12.1
# 29          1  closed_front_1     333   col6     0.0       0.0  0.000000  12.1
# 30          1  closed_front_1     333   col7     0.0       0.0  0.000000  12.1
# 31          1  closed_front_1     333   col8     0.0       0.0  0.000000  12.1
# 32          1  closed_front_1     333   col9     0.0       0.0  0.000000  12.1
# 33          1  closed_front_1     333  col10     1.0      11.0  0.909091  12.1
# 34          1  closed_front_1     333  col11     0.0       0.0  0.000000  12.1
# 35          1  closed_front_1     333  col12     0.0       0.0  0.000000  12.1
# 36          1  closed_front_1     444   col1     1.0       9.0  1.046512   8.6
# 37          1  closed_front_1     444   col2     0.0       0.0  0.000000   8.6
# 38          1  closed_front_1     444   col3     0.0       0.0  0.000000   8.6
# 39          1  closed_front_1     444   col4     0.0       0.0  0.000000   8.6
# 40          1  closed_front_1     444   col5     0.0       0.0  0.000000   8.6
# 41          1  closed_front_1     444   col6     1.0       9.0  1.046512   8.6
# 42          1  closed_front_1     444   col7     0.0       0.0  0.000000   8.6
# 43          1  closed_front_1     444   col8     0.0       0.0  0.000000   8.6
# 44          1  closed_front_1     444   col9     0.0       0.0  0.000000   8.6
# 45          1  closed_front_1     444  col10     0.0       0.0  0.000000   8.6
# 46          1  closed_front_1     444  col11     0.0       0.0  0.000000   8.6
# 47          1  closed_front_1     444  col12     1.0       9.0  1.046512   8.6
# 48          1  closed_front_1     555   col1     0.0       0.0  0.000000  12.1
# 49          1  closed_front_1     555   col2     0.0       0.0  0.000000  12.1
# 50          1  closed_front_1     555   col3     0.0       0.0  0.000000  12.1
# 51          1  closed_front_1     555   col4     0.0       0.0  0.000000  12.1
# 52          1  closed_front_1     555   col5     1.0       9.0  0.743802  12.1
# 53          1  closed_front_1     555   col6     0.0       0.0  0.000000  12.1
# 54          1  closed_front_1     555   col7     0.0       0.0  0.000000  12.1
# 55          1  closed_front_1     555   col8     1.0       9.0  0.743802  12.1
# 56          1  closed_front_1     555   col9     1.0       9.0  0.743802  12.1
# 57          1  closed_front_1     555  col10     0.0       0.0  0.000000  12.1
# 58          1  closed_front_1     555  col11     0.0       0.0  0.000000  12.1
# 59          1  closed_front_1     555  col12     0.0       0.0  0.000000  12.1

# %%
column_k=product_flow[product_flow['Values']==1]

# %%
column_k## one solution
# Out:
#    Machine_id    Machine_type Product Column  Values  Capacity       dos   spd
# 3           1  closed_front_1     111   col4     1.0      11.0  2.037037   5.4
# 6           1  closed_front_1     111   col7     1.0      11.0  2.037037   5.4
# 22          1  closed_front_1     222  col11     1.0      11.0  7.333333   1.5
# 25          1  closed_front_1     333   col2     1.0      11.0  0.909091  12.1
# 26          1  closed_front_1     333   col3     1.0      11.0  0.909091  12.1
# 33          1  closed_front_1     333  col10     1.0      11.0  0.909091  12.1
# 36          1  closed_front_1     444   col1     1.0       9.0  1.046512   8.6
# 41          1  closed_front_1     444   col6     1.0       9.0  1.046512   8.6
# 47          1  closed_front_1     444  col12     1.0       9.0  1.046512   8.6
# 52          1  closed_front_1     555   col5     1.0       9.0  0.743802  12.1
# 55          1  closed_front_1     555   col8     1.0       9.0  0.743802  12.1
# 56          1  closed_front_1     555   col9     1.0       9.0  0.743802  12.1

# %%
k
# Out:
#    Machine_id    Machine_type Product  Capacity       dos   spd
# 3           1  closed_front_1     111      11.0  2.037037   5.4
# 6           1  closed_front_1     111      11.0  2.037037   5.4
# 22          1  closed_front_1     222      11.0  7.333333   1.5
# 25          1  closed_front_1     333      11.0  0.909091  12.1
# 26          1  closed_front_1     333      11.0  0.909091  12.1
# 33          1  closed_front_1     333      11.0  0.909091  12.1
# 36          1  closed_front_1     444       9.0  1.046512   8.6
# 41          1  closed_front_1     444       9.0  1.046512   8.6
# 47          1  closed_front_1     444       9.0  1.046512   8.6
# 52          1  closed_front_1     555       9.0  0.743802  12.1
# 55          1  closed_front_1     555       9.0  0.743802  12.1
# 56          1  closed_front_1     555       9.0  0.743802  12.1

# %%
k=column_k.drop(['Column','Values'], axis=1)

# %%
k
# Out:
#    Machine_id    Machine_type Product  Capacity       dos   spd
# 3           1  closed_front_1     111      11.0  2.037037   5.4
# 6           1  closed_front_1     111      11.0  2.037037   5.4
# 22          1  closed_front_1     222      11.0  7.333333   1.5
# 25          1  closed_front_1     333      11.0  0.909091  12.1
# 26          1  closed_front_1     333      11.0  0.909091  12.1
# 33          1  closed_front_1     333      11.0  0.909091  12.1
# 36          1  closed_front_1     444       9.0  1.046512   8.6
# 41          1  closed_front_1     444       9.0  1.046512   8.6
# 47          1  closed_front_1     444       9.0  1.046512   8.6
# 52          1  closed_front_1     555       9.0  0.743802  12.1
# 55          1  closed_front_1     555       9.0  0.743802  12.1
# 56          1  closed_front_1     555       9.0  0.743802  12.1

# %%
j=k.groupby(['Machine_id','Machine_type','Product']).agg(sum)

# %%
j
# Out:
#                                    Capacity       dos   spd
# Machine_id Machine_type   Product
# 1          closed_front_1 111          22.0  4.074074  10.8
#                           222          11.0  7.333333   1.5
#                           333          33.0  2.727273  36.3
#                           444          27.0  3.139535  25.8
#                           555          27.0  2.231405  36.3

# %%
j['spd']=spdm.values()

# %%
j ## sencond solution
# Out:
#                                    Capacity       dos   spd
# Machine_id Machine_type   Product
# 1          closed_front_1 111          22.0  4.074074   5.4
#                           222          11.0  7.333333   1.5
#                           333          33.0  2.727273  12.1
#                           444          27.0  3.139535   8.6
#                           555          27.0  2.231405  12.1

# %%
z
# Out:
# <gurobi.Var Z (value 2.231404958677686)>

# %%
machine_id	machine_type	col1	col2	col3	col4	col5	col6	col7	col8	col9	col10	col11	col12
1	closed_front_1	111	222	333	444	555	111	222	333	444	555	111	222
